# %%
from clustergrammer_widget import *

# %%
fungalOxalate = Network(clustergrammer_widget)

# %%
# load the combined fungal melanin and oxalotrophy HMMER screen results aggregated and formatted for Clustergrammer.
fungalOxalate.load_file("/Users/ghouse/Documents/SFA/Fungal_oxalotrophy_HMMER/JGI_fungal_annotatedProteinAASeqs/SFA_fungalOxalotrophy_HMMERScreened_aggregatedOutput_6Domains_forClustergrammer_050119.txt")

# %%
fungalOxalate.cluster()

# %%
fungalOxalate.widget()
