# %%
from clustergrammer_widget import *

# %%
fungal_oxalotrophy = Network(clustergrammer_widget)

# %%
# load the fungal oxalotrophy HMMER screen results aggregated and formatted for Clustergrammer.
fungal_oxalotrophy.load_file("/Users/ghouse/Documents/SFA/Fungal_oxalotrophy_HMMER/JGI_fungal_annotatedProteinAASeqs/SFA_fungalOxalotrophy_HMMERScreened_aggregatedOutput_forClustergrammer_040919.txt")
# Out:
# /Users/ghouse/miniconda3/envs/clustergrammer/lib/python3.6/site-packages/clustergrammer_widget/clustergrammer/load_data.py:70: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   tmp_df['mat'] = pd.read_table(file_buffer, index_col=row_arr)

# %%
fungal_oxalotrophy.cluster()

# %%
fungal_oxalotrophy.widget()
