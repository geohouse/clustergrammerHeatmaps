# %%
from clustergrammer_widget import *

# %%
updated_10Domain_v2 = Network(clustergrammer_widget)

# %%
# load the updated data including the new HMMER-enforced 190 bit score threshold
# for the combined THN reductase model results instead of the previous e-value threshold cutoff.
# The bit score value was found and applied following information on the PFAM and HMMER webpages 
# (http://pfam.xfam.org/help?tab=helpScoresBlock#tabview=tab6)
updated_10Domain_v2.load_file("/Users/ghouse/Documents/SFA/Fungal_melanin/JGI_fungal_annotatedProteinAASeqs/SFA_aggregated_combinedAll_10_Models_HMMER_aaResults_usingDomainTableFiles_032719_forClustergrammer_v2.txt")
# Out:
# /Users/ghouse/miniconda3/envs/clustergrammer/lib/python3.6/site-packages/clustergrammer_widget/clustergrammer/load_data.py:68: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   header=col_arr)

# %%
updated_10Domain_v2.cluster()

# %%
updated_10Domain_v2.widget()
