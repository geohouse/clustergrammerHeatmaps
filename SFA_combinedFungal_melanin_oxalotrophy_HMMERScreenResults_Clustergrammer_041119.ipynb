# %%
from clustergrammer_widget import *

# %%
combinedFungal_melanin_oxalotrophy = Network(clustergrammer_widget)

# %%
# load the combined fungal melanin and oxalotrophy HMMER screen results aggregated and formatted for Clustergrammer.
combinedFungal_melanin_oxalotrophy.load_file("/Users/ghouse/Documents/SFA/combined_fungalMelaninAndOxalotrophy_HMMERScreens/SFA_combinedFungalMelanin_oxalotrophy_HMMERScreenResultsForClustergrammer_041119.tsv")
# Out:
# /Users/ghouse/miniconda3/envs/clustergrammer/lib/python3.6/site-packages/clustergrammer_widget/clustergrammer/load_data.py:68: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   header=col_arr)

# %%
combinedFungal_melanin_oxalotrophy.cluster()

# %%
combinedFungal_melanin_oxalotrophy.widget()
