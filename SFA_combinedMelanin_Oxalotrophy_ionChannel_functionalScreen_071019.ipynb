# %%
from clustergrammer_widget import *

# %%
SFA_fungalCombinedFunctionalScreen_071019 = Network(clustergrammer_widget)

# %%
# load the combined fungal melanin and oxalotrophy HMMER screen results aggregated and formatted for Clustergrammer.
SFA_fungalCombinedFunctionalScreen_071019.load_file("/Users/ghouse/Documents/SFA/Fungal_melanin/SFA_automatedFunctionalScans/SFA_JGIFungalFunctionalScreens_Melanin_Oxalate_IonTransporters_clustergrammerResults_071019_processedHMMERResultsFileForClustergrammer_targetLevelOutput.tsv")
# Out:
# /Users/ghouse/miniconda3/envs/clustergrammer/lib/python3.6/site-packages/clustergrammer_widget/clustergrammer/load_data.py:70: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   tmp_df['mat'] = pd.read_table(file_buffer, index_col=row_arr)

# %%
SFA_fungalCombinedFunctionalScreen_071019.cluster()

# %%
SFA_fungalCombinedFunctionalScreen_071019.widget()
